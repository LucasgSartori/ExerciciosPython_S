# %% [markdown]
# # Projeto Final
# ## Base de dados **Hotel Reservations**
# - https://www.kaggle.com/datasets/ahsan81/hotel-reservations-classification-dataset
#
# #### Submissão: [Google-Forms](https://forms.gle/kKjVGvuboHb4LD4S9)
# #### Prazo de envio: **09/12/2024**

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\572758\Documents\GitHub\POC1Copacol\POC1Copacol\Hotel-Reservations 1.csv")
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# 2        Room_Type 1          1          2018              2            28
# 3        Room_Type 1        211          2018              5            20
# 4        Room_Type 1         48          2018              4            11
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests booking_status
# 0                       0   Not_Canceled
# 1                       1   Not_Canceled
# 2                       0       Canceled
# 3                       0       Canceled
# 4                       0       Canceled

# %% [markdown]
# ## Exercício 1: Utilizando a função apply
# Crie uma nova coluna chamada `stay_duration` a partir da soma de `no_of_weekend_nights` e `no_of_week_nights`.

# %%
df['stay_duration'] = df['no_of_weekend_nights'] + df['no_of_week_nights']
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# 2        Room_Type 1          1          2018              2            28
# 3        Room_Type 1        211          2018              5            20
# 4        Room_Type 1         48          2018              4            11
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests booking_status  stay_duration
# 0                       0   Not_Canceled              3
# 1                       1   Not_Canceled              5
# 2                       0       Canceled              3
# 3                       0       Canceled              2
# 4                       0       Canceled              2

# %% [markdown]
# ## Exercício 2: Utilizando a função transform
# - Aplique a normalização (escalonamento entre 0 e 1) Min-Max na coluna `avg_price_per_room`.
# - **Normalização Min-Max**:
# $
# x' = \frac{x - x_{\text{min}}}{x_{\text{max}} - x_{\text{min}}}
# $
#
# ### Onde:
# - \( $x$ \): Valor original.
# - \( $x'$ \): Valor normalizado (entre 0 e 1).
# - \( $x_{\text{min}}$ \): Valor mínimo do conjunto de dados.
# - \( $x_{\text{max}}$ \): Valor máximo do conjunto de dados.

# %%
min_val = df["avg_price_per_room"].min()
max_val = df["avg_price_per_room"].max()

# %%
df["avg_price_per_room_normalized"] = (df["avg_price_per_room"] - min_val) / (max_val - min_val)
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  ...  arrival_date  \
# 0        Room_Type 1        224          2017  ...             2
# 1        Room_Type 1          5          2018  ...             6
# 2        Room_Type 1          1          2018  ...            28
# 3        Room_Type 1        211          2018  ...            20
# 4        Room_Type 1         48          2018  ...            11
#
#    market_segment_type repeated_guest  no_of_previous_cancellations  \
# 0              Offline              0                             0
# 1               Online              0                             0
# 2               Online              0                             0
# 3               Online              0                             0
# 4               Online              0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests  booking_status stay_duration  \
# 0                       0    Not_Canceled             3
# 1                       1    Not_Canceled             5
# 2                       0        Canceled             3
# 3                       0        Canceled             2
# 4                       0        Canceled             2
#
#    avg_price_per_room_normalized
# 0                       0.120370
# 1                       0.197556
# 2                       0.111111
# 3                       0.185185
# 4                       0.175000
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Exercício 3: Substituições com replace e regex
# Altere a coluna `room_type_reserved` extraindo apenas os números da coluna.

# %%
df["room_type_reserved"] = df["room_type_reserved"].replace(to_replace=r"\D", value="", regex=True)
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  ...  arrival_date  \
# 0                  1        224          2017  ...             2
# 1                  1          5          2018  ...             6
# 2                  1          1          2018  ...            28
# 3                  1        211          2018  ...            20
# 4                  1         48          2018  ...            11
#
#    market_segment_type repeated_guest  no_of_previous_cancellations  \
# 0              Offline              0                             0
# 1               Online              0                             0
# 2               Online              0                             0
# 3               Online              0                             0
# 4               Online              0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests  booking_status stay_duration  \
# 0                       0    Not_Canceled             3
# 1                       1    Not_Canceled             5
# 2                       0        Canceled             3
# 3                       0        Canceled             2
# 4                       0        Canceled             2
#
#    avg_price_per_room_normalized
# 0                       0.120370
# 1                       0.197556
# 2                       0.111111
# 3                       0.185185
# 4                       0.175000
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Exercício 4: Gráfico Mapa de Calor
# Faça a plotagem do Mapa de calor (**Heatmap**) entre as colunas numéricas

# %%
number_column = df.select_dtypes(include=['number'])
corr = number_column.corr()


plt.figure(figsize=(12, 8))
sb.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)
plt.title("Mapa de Calor entre Colunas Numéricas")
plt.show()

# %% [markdown]
# ## Exercício 5: Expressões Regulares
# Altere a coluna `Booking_ID`, extraindo apenas os números da coluna.

# %%
df["Booking_ID"] = df["Booking_ID"].replace(to_replace=r"\D", value="", regex=True)
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0      00001             2               0                     1
# 1      00002             2               0                     2
# 2      00003             1               0                     2
# 3      00004             2               0                     0
# 4      00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  ...  arrival_date  \
# 0                  1        224          2017  ...             2
# 1                  1          5          2018  ...             6
# 2                  1          1          2018  ...            28
# 3                  1        211          2018  ...            20
# 4                  1         48          2018  ...            11
#
#    market_segment_type repeated_guest  no_of_previous_cancellations  \
# 0              Offline              0                             0
# 1               Online              0                             0
# 2               Online              0                             0
# 3               Online              0                             0
# 4               Online              0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests  booking_status stay_duration  \
# 0                       0    Not_Canceled             3
# 1                       1    Not_Canceled             5
# 2                       0        Canceled             3
# 3                       0        Canceled             2
# 4                       0        Canceled             2
#
#    avg_price_per_room_normalized
# 0                       0.120370
# 1                       0.197556
# 2                       0.111111
# 3                       0.185185
# 4                       0.175000
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Exercício 6: Gráfico de Dispersão
# Faça a plotagem com a relação entre `lead_time` e `avg_price_per_room` (sem a normalização).

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['lead_time'], df['avg_price_per_room'], alpha=0.5)
plt.title('Relação entre Lead Time e Preço Médio por Quarto')
plt.xlabel('Lead Time')
plt.ylabel('Preço Médio por Quarto')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercício 7: Groupby e Agg
# Calcule o preço médio (`avg_price_per_room`), sem normalização, por tipo de quarto (`room_type_reserved`).

# %%
preco_medio_tp_quarto = df.groupby('room_type_reserved')['avg_price_per_room'].agg('mean')
print(preco_medio_tp_quarto)
# Out:
# room_type_reserved
# 1     95.918532
# 2     87.848555
# 3     73.678571
# 4    125.287317
# 5    123.733623
# 6    182.212836
# 7    155.198291
# Name: avg_price_per_room, dtype: float64

# %% [markdown]
# ## Exercício 8: Boxplot
# Apresente o boxplot com os dados de preço médio (`avg_price_per_room`), sem normalização, por tipo de quarto (`room_type_reserved`).

# %%
plt.figure(figsize=(10, 6))
sb.boxplot(x='room_type_reserved', y='avg_price_per_room', data=df)
plt.title('Boxplot do Preço Médio por Tipo de Quarto')
plt.xlabel('Tipo de Quarto')
plt.ylabel('Preço Médio por Quarto')
plt.show()
